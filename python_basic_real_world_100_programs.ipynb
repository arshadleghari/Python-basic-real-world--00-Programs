# %% [markdown]
# # Python Basic Real World 100 Programs
# Author: Arshad Mehmood
# Level: Beginner
# Topics:
# - Math
# - List
# - Tuple
# - Dictionary

# %%
# 1-- Given a=10, b=3, compute q (integer division), r (remainder), f (float division).
a=10
b=3
q = a // b  # // use for integer division dont show the the result in decimal
r = a % b   # % use for remainder
f = a / b   # / use for float division
print(q)  
print(r)
print(f)
# Out:
# 3
# 1
# 3.3333333333333335

# %%
# program 2
x = 2
x = x - 1
x = x + 1
x = x * 2
x = x / 2
print(x)
# Out:
# 2.0

# %%
#program 3
a = 5
b = 10
# a = b
b = a
# print(a)
print(b)
# Out:
# 5

# %%
# program 4
price = 450
discount = 15 
d = 450 * 15 / 100
print(d)
# Out:
# 67.5

# %%
#program 5
seconds = 36072
# hours = ?  1 hour = 3600 seconds
# mint = ?    1 mint = 60 seconds
# remaining seconds = ?
hours = seconds // 3600  
mint = (seconds % 3600) // 60
seconds = seconds % 60


print(hours)
print(mint)
print(seconds)
# Out:
# 10
# 1
# 12

# %%
#program 6 copnute 1st and last digit of a give
n=12345
first_digit = n // 10000
last_digit = n % 10
print(first_digit)
print(last_digit)
# Out:
# 1
# 5

# %%
# program 7
length = 12
width = 8
area = length * width
premiter = 2 * (length + width)
print(area)
print(premiter)
# Out:
# 96
# 40

# %%
# program 8
celsius = 37
# fahrenheit = (celsius * 9/5) + 32 formula to convert celsius to fahrenheit
fahrenheit = (celsius * 9/5) + 32
print(fahrenheit)


fahrenheit = 98.6
celsius = (fahrenheit - 32) * 5/9
print(celsius)
# Out:
# 98.6
# 37.0

# %%
#program 9
radius = 7
pi = 3.14
area = pi * radius * radius
print(area)
# Out:
# 153.86

# %%
#program 10
a = 2
b = 5
c = 3

x = (a + b) * c
y = a+b*c
print(x)
print(y)
# Out:
# 21
# 17

# %%
# program 11
salary = 50000
Tax =0.07
tax_amount = salary * Tax
net_salary = salary - tax_amount
print(tax_amount)
print(net_salary)
# Out:
# 3500.0000000000005
# 46500.0

# %%
# progrma 12  
x = 5
xsquared = x * x
xcubed = xsquared * x
print(xsquared)
print(xcubed)
# Out:
# 25
# 125

# %%
#program 13
total = 999
people = 6
x =total//people
print(x)
# Out:
# 166.5

# %%
# program14
km =120
# meter=?   ----1km 1000 m
# centemeter = km * 1000 ---1m 100cm
meter=km*1000
centemeter = meter * 100
print(meter)    
print(centemeter)
# Out:
# 120000
# 12000000

# %%
# program 15
p=3
t=2
r=5
x = (p * t * r) / 100
print(x)
# Out:
# 0.3

# %%
# program16 average of 2 numbers
a=8
b=12
x = (a+b)/2
print(x)
# Out:
# 10.0

# %%
# program 17 
x = 10
x = x + (x * 0.1)
print(x)
# Out:
# 11.0

# %%
# Program 18  
x =25
x = x//2
x = x%2
print(x)
# Out:
# 0

# %%
# program 19
a=9
b=4
x = a/b
print(x)
# Out:
# 2.25

# %%
#program 20
a =100
discount = 10/100
final_price = a - (a * discount)
print(final_price)
# Out:
# 90.0

# %% [markdown]
# # Part B  string

# %%
# program 21
s ="python"

print(s[0])
print(s[1])
print(s[5])
print(s[3])
# Out:
# p
# y
# n
# h

# %%
# program 22
s ="Helo World"
x = s[4:10]
print(x)
# Out:
#  World

# %%
#program 23 
s="  Data Science  "
print(s.strip())
# Out:
# Data Science

# %%
#program 24
s="BANANA"
print(s.lower())
# Out:
# banana

# %%
# program 25
s="paKisTaN"
print(s.upper())

s="paKisTaN"
print(s.lower())
# Out:
# PAKISTAN
# pakistan

# %%
#program 26  
s="abc123"
a =s[0:3]
b =s[3:]
print(a)
print(b)
# Out:
# abc
# 123

# %%
#program 27
s="mississippi"
print(s.count('s'))
# Out:
# 4

# %%
# program 28
s="one,two,three"
a = s.split(",")
print(a)
# Out:
# ['one', 'two', 'three']

# %%
# program 29
words=["I","love","Python"]
sentence =" ".join(words)
print(sentence)
# Out:
# I love Python

# %%
#program 30
s="2026-01-20"
year,month,day = s.split("-")
print(year,month,day)
# Out:
# 2026 01 20

# %%
#program 31
s="hello"
a= "-".join(s)
print(a)
# Out:
# h- e- l- l- o

# %%
# program 32
s="abcdef"
a=s[: :-1] # This reverses the string how
print(a)
# Out:
# fedcba

# %%
# program 33
s="banana"
a =s.replace("na","NA")
print(a)
# Out:
# baNANA

# %%
#program 34
s="Email: test@gmail.com"
a=(s.find("@"))
print(a)
# Out:
# 11

# %%
# program35
s="path/to/file.txt"
a = s.split("/")[-1]
print(a)
# Out:
# file.txt

# %%
#program 36
s="file.txt"
a = s.split(".")[-1]
print(a)
# Out:
# txt

# %%
#program 37
s="a,b,c,d"
a=s.split(",")[1]
print(a)
# Out:
# b

# %%
# PROGRAM 38
s="Hello123"
a =s.isalnum()
print(a)
# Out:
# True

# %%
#program 39
s="programming"
a=s[3:7]
print(a)
# Out:
# gram

# %%
#program 40
first="Hazrat"
last="Bilal"
a = first+last
print(a)
# Out:
# HazratBilal

# %%
# program 41
s="I like tea"
a=s.replace("tea",("coffee"))
print(a)
# Out:
# I like coffee

# %%
# program42
s="aaaab"
a=s.count("a")
b=s.count("ab")
print(a)
print(b)
# Out:
# 4
# 1

# %%
# program 43
s="user_name"
a=s.replace("_","")
print(a)
# Out:
# username

# %%
# program 44
s="one two  three"
a=s.split()
print(a)
# Out:
# ['one', 'two', 'three']

# %%
# program 45
s="0123456789"
a=s[0:10:2]
print(a)
# Out:
# 02468

# %% [markdown]
# # Opertions on lists

# %%
# program 46
lst=[10,20,30,40] 
a = lst[0]
b = lst[-1]
x = a+b
print(x)
# Out:
# 50 50

# %%
#program 47 append 4 to the list
lst=[1,2,3]
lst.append(4)
print(lst)
# Out:
# [1, 2, 3, 4]

# %%
#program 48 
lst=[1,2,3]
lst.extend([4,5])
print(lst)
# Out:
# [1, 2, 3, 4, 5]

# %%
#program 49
lst=[5,6,7]
lst.insert(1,99)
print(lst)
# Out:
# [5, 99, 6, 7]

# %%
#program 50
lst=[1,2,3,2,2]
count=lst.count(2)
print(count)
# Out:
# 3

# %%
# program 51
lst=[9,8,7]
lst.reverse()
print(lst)
# Out:
# [7, 8, 9]

# %%
# Program 52
lst=[3,1,2]
lst.sort()
print(lst)
# Out:
# [1, 2, 3]

# %%
# program 53
lst=[3,1,2]
lst.sort(reverse=True)
print(lst)
# Out:
# [3, 2, 1]

# %%
# Program 54
lst=["a","b","c","d"]
x= lst[1:3]
print(x)
# Out:
# ['b', 'c']

# %%
#program 55 sublist
lst=[10,20,30,40,50]
x=lst[2:5]
print(x)
# Out:
# [30, 40, 50]

# %%
#program 56 
lst=[1,2,3,4]
lst2=lst*2
print(lst2)
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]

# %%
# Program 57 
lst=["apple","banana","mango"]
lst[1]=("orange")
print(lst)
# Out:
# ['apple', 'orange', 'mango']

# %%
#program 58
lst=[1,2,3,4]
lst.remove(3)
print(lst)
# Out:
# [1, 2, 4]

# %%
#program 59 
lst=[1,2,3,4] # first element into last variable x
x=lst.pop(0)
print(x)
# Out:
# 1

# %%
# program 60 
lst=[1,2,3,4]
x=lst.pop(1)
print(x)
# Out:
# 2

# %%
# program 61
lst=[10,20,30]
lst[1] = 999
print(lst)
# Out:
# [10, 999, 30]

# %%
# program 62   get even-index elements using slicing.
lst=[1,2,3,4,5]
x=lst[0:5:2]
print(x)
# Out:
# [1, 3, 5]

# %%
#program 63 get odd-index elements using slicing.
lst=[1,2,3,4,5]
x=lst[1:5:2]
print(x)
# Out:
# [2, 4]

# %%
#program 64 
lst=[1,2,3]
lst2=[4,5,6]
nested_lst=[lst,lst2]
print(nested_lst)
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
#program 65
lst=[1,2,3]
lst2=lst
lst2[0]=999
lst2.copy()
print(lst2)
# Out:
# [999, 2, 3]

# %%
#program 66
lst=["a","b","c"]
print(",".join(lst))
# Out:
# a,b,c

# %%
#program 67 
lst=["a","b","c"]
print(",".join(lst))
# Out:
# a,b,c

# %%
# 68 lst=[1,2,3,4]
lst=[1,2,3,4]
x=3 in lst
print(x)
# Out:
# True

# %%
#69 Given lst=[1,2,3,4]
lst=[1,2,3,4]
x=lst.index(4)
print(x)



# 70. Given lst=[1,2,3,4]
lst=[1,2,3,4]
x=lst[0:2]+lst[2:4]
print(x)
# Out:
# 3
# [1, 2, 3, 4]

# %% [markdown]
# #  D) Tuples (71–80)

# %%
# 71 Given t=(10,20,30)
t=(10,20,30)
print(t[0])
print(t[-1])

# 72. Given t=("a","b","c","d"), slice ("b","c").
t=("a","b","c","d")
x=t[1:3]
print(x)

# 73. Given t=(1,2,3), do tuple unpacking into a,b,c.
t=(1,2,3)
a,b,c = t
print(a)
print(b)
print(c)


# 74. Given t=(5,10), swap into a,b via unpacking.
t=(5,10)
a,b = t
print(a)
print(b)

# 75. Given t=(1,2,3,2,2), count how many `2`s.
t=(1,2,3,2,2)
count = t.count(2)
print(count)

# 76. Convert lst=[1,2,3] into tuple t.
lst=[1,2,3]
t=tuple(lst)
print(t)

# 77. Convert t=(1,2,3) into list lst.
t=(1,2,3)
lst=list(t)
print(lst)

# 78. Given t=("Hazrat","Bilal"), create string "Hazrat Bilal" using join.
t=("Hazrat","Bilal")
s=" ".join(t)


# 79. Given t=(1,2,3), create t2=t+(4,5).
t=(1,2,3)
t2=t+(4,5)  
print(t2)

# 80. Given t=(1,2,3,4,5), get middle element(s) using indexing
t=(1,2,3,4,5)
x=t[2]
print(x)
# Out:
# 10
# 30
# ('b', 'c')
# 1
# 2
# 3
# 5
# 10
# 3
# (1, 2, 3)
# [1, 2, 3]
# (1, 2, 3, 4, 5)
# 3

# %% [markdown]
# # E) Dictionaries (81–100)

# %%
# 81. Create a dictionary for a student: name, age, cgpa (3 keys).
student = {
    "name" : "Ali",
    "age" : 20,
    "cgpa" : 3.5
}
print(student)
# Out:
# {'name': 'Ali', 'age': 20, 'cgpa': 3.5}

# %%
#82
d={"a":10,"b":20}
print(d["b"])
# Out:
# 20

# %%
# 83. Given d={"a":10,"b":20}, update "b" to 999.
d={"a":10,"b":20}
d["b"]=999
print(d)
# Out:
# {'a': 10, 'b': 999}

# %%
#84
d={"a":10,"b":20}
d["c"]=30
print(d)
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
# 85. Given d={"a":10,"b":20}, remove key "a" using .pop() into a variable
d={"a":10,"b":20}
x=d.pop("a")
print(x)
# Out:
# 10

# %%
#86 check city in list
d={"name":"Ali","city":"Quetta"}
x = "city" in d
print(x)
# Out:
# True

# %%
#87 d={"x":1}, safely read missing key "y" with default 0 using .get()
d={"x":1}
print(d.get("y",0))
# Out:
# 0

# %%
# 88 Given d={"math":80,"english":75,"cs":90}, compute total of all 3 using direct access.
d={"math":80,"english":75,"cs":90}
total = d["math"] + d["english"] + d["cs"]
print(total)
# Out:
# 245

# %%
#89 Given d={"p":5,"q":10}, make a tuple of items list: list(d.items()).
d={"p":5,"q":10}
print(list(d.items()))
# Out:
# [('p', 5), ('q', 10)]

# %%
#90 d={"a":1,"b":2}
d={"a":1,"b":2}
keys_list = list(d.keys())
value_list = list(d.values())
print(keys_list)
print(value_list)
# Out:
# ['a', 'b']
# [1, 2]

# %%
#91 d={"name":"Hazrat","role":"Developer"}, using dict
# d={"name":"Hazrat","role":"Developer"}
dict={
   "Name" : "Hazrat Bilal",
   "Role" : " Is Developer" 
}
value_list= list(dict.values())
# print(dict)
print(value_list)
# Out:
# ['Hazrat Bilal', ' Is Developer']

# %%
#92
# d={"a":1,"b":2,"c":3}
d={"a":1,"b":2,"c":3}
d2=d.copy()
d2["a"]=999
print(d2)
print(d)
# Out:
# {'a': 999, 'b': 2, 'c': 3}
# {'a': 1, 'b': 2, 'c': 3}

# %%
#93
d={"price":100,"tax":0.05}
final_price = d["price"] + (d["price"] * d["tax"])
print(final_price)
# Out:
# 105.0

# %%
# 94
d={"first":"Hazrat","last":"Bilal"} 
full_name = d["first"] + " " + d["last"]
print(full_name)
# Out:
# Hazrat Bilal

# %%
#95
d={"items":[1,2,3]}
d["items"].append(4)
print(d)
# Out:
# {'items': [1, 2, 3, 4]}

# %%
#96 using tuple extract x y
d={"coords":(10,20)}
x,y=d["coords"]
print(x,y)
# Out:
# 10 20

# %%
# 97 d={"a":1,"b":2}
d={"a":1,"b":2}
d2={1:"a",2:"b"}
print(d2)
# Out:
# {1: 'a', 2: 'b'}

# %%
# 98 
d={"a":10,"b":20,"c":30}
a=d.get("c")
print(a)
# Out:
# 30

# %%
#99
d={"username":"abc","password":"123"}
d["password"]="***"
print(d)
# Out:
# {'username': 'abc', 'password': '***'}

# %%
#100
d={"full_name":"Hazrat Bilal"}
fisrt_name, last_name = d["full_name"].split(" ")
print(fisrt_name, last_name)
# Out:
# Hazrat Bilal
